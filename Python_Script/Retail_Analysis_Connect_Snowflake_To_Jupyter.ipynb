# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in d:\anaconda\lib\site-packages (3.7.1)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.11.0)
# Requirement already satisfied: requests<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.28.1)
# Requirement already satisfied: tomlkit in d:\anaconda\lib\site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: typing-extensions<5,>=4.3 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (4.10.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (1.15.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from snowflake-connector-python) (22.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2022.12.7)
# Requirement already satisfied: filelock<4,>=3.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.9.0)
# Requirement already satisfied: pyjwt<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.0.4)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (23.0.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (39.0.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2023.3)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-sqlalchemy
# Out:
# Collecting snowflake-sqlalchemy
#   Downloading snowflake_sqlalchemy-1.5.1-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from snowflake-sqlalchemy) (1.4.39)
# Requirement already satisfied: snowflake-connector-python<4.0.0 in d:\anaconda\lib\site-packages (from snowflake-sqlalchemy) (3.7.1)
# Requirement already satisfied: requests<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.4)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (39.0.1)
# Requirement already satisfied: pyjwt<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.4.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (22.0)
# Requirement already satisfied: filelock<4,>=3.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.9.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.11.0)
# Requirement already satisfied: typing-extensions<5,>=4.3 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (4.4.0)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2022.12.7)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.4.0)
# Requirement already satisfied: tomlkit in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (0.11.1)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (23.0.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.15.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.5.1)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy<2.0.0,>=1.4.0->snowflake-sqlalchemy) (2.0.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.26.14)
# Installing collected packages: snowflake-sqlalchemy
# Successfully installed snowflake-sqlalchemy-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import snowflake.connector

# %%
account = 'SV41368'
user = 'admin'
password = 'Admin@12345'
database = 'RETAILS'
schema = 'PUBLIC'
warehouse = 'DEMO_DWH'

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in d:\anaconda\lib\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in d:\anaconda\lib\site-packages (from pandas_profiling) (4.6.5)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.5.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (4.64.1)
# Requirement already satisfied: pydantic>=2 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (2.6.3)
# Requirement already satisfied: phik<0.13,>=0.11.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.4)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.10.0)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.13.5)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (3.1.2)
# Requirement already satisfied: typeguard<5,>=4.1.2 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (4.1.5)
# Requirement already satisfied: wordcloud>=1.9.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.3)
# Requirement already satisfied: numpy<1.26,>=1.16.0 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.23.5)
# Requirement already satisfied: numba<0.59.0,>=0.56.0 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.56.4)
# Requirement already satisfied: requests<3,>=2.24.0 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (2.28.1)
# Requirement already satisfied: dacite>=1.8 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.8.1)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (3.7.0)
# Requirement already satisfied: imagehash==4.3.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (1.11.2)
# Requirement already satisfied: htmlmin==0.1.12 in d:\anaconda\lib\site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (9.4.0)
# Requirement already satisfied: PyWavelets in d:\anaconda\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (1.4.1)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (22.1.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (2.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas_profiling) (22.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling->pandas_profiling) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in d:\anaconda\lib\site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling->pandas_profiling) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas_profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in d:\anaconda\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling->pandas_profiling) (4.10.0)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling->pandas_profiling) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling->pandas_profiling) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.14)
# Requirement already satisfied: patsy>=0.5.2 in d:\anaconda\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.3)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas_profiling) (0.4.6)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\anaconda\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in d:\anaconda\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in d:\anaconda\lib\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in d:\anaconda\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_scheduler
# Out:
# Collecting jupyter_scheduler
#   Downloading jupyter_scheduler-2.5.1-py3-none-any.whl (518 kB)
#      ------------------------------------ 518.4/518.4 kB 664.3 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-server<3,>=1.6 in d:\anaconda\lib\site-packages (from jupyter_scheduler) (1.23.4)
# Collecting nbconvert~=7.0
#   Downloading nbconvert-7.16.2-py3-none-any.whl (257 kB)
#      ------------------------------------ 257.3/257.3 kB 658.9 kB/s eta 0:00:00
# Collecting pytz==2023.3
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ------------------------------------ 502.3/502.3 kB 572.9 kB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy~=1.0 in d:\anaconda\lib\site-packages (from jupyter_scheduler) (1.4.39)
# Collecting croniter~=1.4
#   Downloading croniter-1.4.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: psutil~=5.9 in d:\anaconda\lib\site-packages (from jupyter_scheduler) (5.9.0)
# Collecting fsspec==2023.6.0
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ------------------------------------ 163.8/163.8 kB 893.0 kB/s eta 0:00:00
# Requirement already satisfied: traitlets~=5.0 in d:\anaconda\lib\site-packages (from jupyter_scheduler) (5.7.1)
# Requirement already satisfied: pydantic<3,>=1.10 in d:\anaconda\lib\site-packages (from jupyter_scheduler) (2.6.3)
# Requirement already satisfied: python-dateutil in d:\anaconda\lib\site-packages (from croniter~=1.4->jupyter_scheduler) (2.8.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (3.5.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (22.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.17.1)
# Requirement already satisfied: jupyter-core>=4.7.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (5.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (7.3.4)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (3.1.2)
# Requirement already satisfied: prometheus-client in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.14.1)
# Requirement already satisfied: Send2Trash in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (5.7.0)
# Requirement already satisfied: websocket-client in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.58.0)
# Requirement already satisfied: argon2-cffi in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (23.2.0)
# Requirement already satisfied: pywinpty in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (2.0.10)
# Requirement already satisfied: tornado>=6.1.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (6.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (0.1.2)
# Requirement already satisfied: tinycss2 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (1.2.1)
# Requirement already satisfied: markupsafe>=2.0 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (2.1.1)
# Requirement already satisfied: pygments>=2.4.1 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (2.11.2)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (4.11.1)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (1.5.0)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      -------------------------------------- 48.0/48.0 kB 820.0 kB/s eta 0:00:00
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (0.5.13)
# Requirement already satisfied: defusedxml in d:\anaconda\lib\site-packages (from nbconvert~=7.0->jupyter_scheduler) (0.7.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.10->jupyter_scheduler) (4.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.10->jupyter_scheduler) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.10->jupyter_scheduler) (2.16.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy~=1.0->jupyter_scheduler) (2.0.1)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (1.2.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (3.4)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda\lib\site-packages (from bleach!=5.0.0->nbconvert~=7.0->jupyter_scheduler) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach!=5.0.0->nbconvert~=7.0->jupyter_scheduler) (0.5.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (1.5.6)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (0.4)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<3,>=1.6->jupyter_scheduler) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<3,>=1.6->jupyter_scheduler) (3.11.0)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (4.17.3)
# Requirement already satisfied: fastjsonschema in d:\anaconda\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->nbconvert~=7.0->jupyter_scheduler) (2.3.2.post1)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (1.15.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (2.21)
# Installing collected packages: pytz, mistune, fsspec, croniter, nbconvert, jupyter_scheduler
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.7
#     Uninstalling pytz-2022.7:
#       Successfully uninstalled pytz-2022.7
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
# Successfully installed croniter-1.4.1 fsspec-2023.6.0 jupyter_scheduler-2.5.1 mistune-3.0.2 nbconvert-7.16.2 pytz-2023.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.

# %%
pip install jupyterlab-scheduler
# Out:
# Collecting jupyterlab-scheduler
#   Downloading jupyterlab_scheduler-0.1.5-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 1.1 MB/s eta 0:00:00
# Collecting jupyterlab~=3.1.4
#   Downloading jupyterlab-3.1.19-py3-none-any.whl (8.6 MB)
#      ---------------------------------------- 8.6/8.6 MB 1.3 MB/s eta 0:00:00
# Collecting papermill~=2.1
#   Downloading papermill-2.5.0-py3-none-any.whl (38 kB)
# Collecting python-crontab~=2.5
#   Downloading python_crontab-2.7.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: nbclassic~=0.2 in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (0.5.2)
# Requirement already satisfied: jupyterlab-server~=2.3 in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (2.19.0)
# Requirement already satisfied: ipython in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (8.10.0)
# Requirement already satisfied: jinja2>=2.1 in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (3.1.2)
# Requirement already satisfied: tornado>=6.1.0 in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (6.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (22.0)
# Requirement already satisfied: jupyter-core in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (5.2.0)
# Requirement already satisfied: jupyter-server~=1.4 in d:\anaconda\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (1.23.4)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (2.28.1)
# Requirement already satisfied: tqdm>=4.32.2 in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (4.64.1)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (0.4)
# Requirement already satisfied: tenacity>=5.0.2 in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (8.0.1)
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (8.0.4)
# Requirement already satisfied: nbformat>=5.1.2 in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (5.7.0)
# Requirement already satisfied: nbclient>=0.2.0 in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (0.5.13)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (6.0)
# Requirement already satisfied: python-dateutil in d:\anaconda\lib\site-packages (from python-crontab~=2.5->jupyterlab-scheduler) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2>=2.1->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.1.1)
# Requirement already satisfied: prometheus-client in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.14.1)
# Requirement already satisfied: argon2-cffi in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.17.1)
# Requirement already satisfied: pywinpty in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.10)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (7.3.4)
# Requirement already satisfied: traitlets>=5.1 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.7.1)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (7.16.2)
# Requirement already satisfied: websocket-client in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.58.0)
# Requirement already satisfied: Send2Trash in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (23.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.5.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\lib\site-packages (from jupyter-core->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.11.0)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter-core->jupyterlab~=3.1.4->jupyterlab-scheduler) (305.1)
# Requirement already satisfied: babel>=2.10 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.11.0)
# Requirement already satisfied: jsonschema>=4.17.3 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.17.3)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.9.6)
# Requirement already satisfied: ipython-genutils in d:\anaconda\lib\site-packages (from nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\anaconda\lib\site-packages (from nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.6)
# Requirement already satisfied: notebook-shim>=0.1.0 in d:\anaconda\lib\site-packages (from nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.2)
# Requirement already satisfied: ipykernel in d:\anaconda\lib\site-packages (from nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (6.19.2)
# Requirement already satisfied: fastjsonschema in d:\anaconda\lib\site-packages (from nbformat>=5.1.2->papermill~=2.1->jupyterlab-scheduler) (2.16.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->papermill~=2.1->jupyterlab-scheduler) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->papermill~=2.1->jupyterlab-scheduler) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->papermill~=2.1->jupyterlab-scheduler) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests->papermill~=2.1->jupyterlab-scheduler) (2.0.4)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.32.2->papermill~=2.1->jupyterlab-scheduler) (0.4.6)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.18.1)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.11.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.0.36)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.1.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil->python-crontab~=2.5->jupyterlab-scheduler) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda\lib\site-packages (from babel>=2.10->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (22.1.0)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.0.2)
# Requirement already satisfied: tinycss2 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.2.1)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\lib\site-packages (from ipykernel->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.1.2)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ipykernel->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\lib\site-packages (from ipykernel->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.1)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.2)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.3.2.post1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.21)
# Installing collected packages: python-crontab, papermill, jupyterlab, jupyterlab-scheduler
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 3.5.3
#     Uninstalling jupyterlab-3.5.3:
#       Successfully uninstalled jupyterlab-3.5.3
# Successfully installed jupyterlab-3.1.19 jupyterlab-scheduler-0.1.5 papermill-2.5.0 python-crontab-2.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in d:\anaconda\lib\site-packages (3.7.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from snowflake-connector-python) (22.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (39.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.0.4)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.11.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: pyjwt<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2023.3)
# Requirement already satisfied: typing-extensions<5,>=4.3 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (4.10.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (1.15.1)
# Requirement already satisfied: requests<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.28.1)
# Requirement already satisfied: filelock<4,>=3.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (3.9.0)
# Requirement already satisfied: tomlkit in d:\anaconda\lib\site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2022.12.7)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python) (23.0.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-sqlalchemy
# Out:
# Requirement already satisfied: snowflake-sqlalchemy in d:\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from snowflake-sqlalchemy) (1.4.39)
# Requirement already satisfied: snowflake-connector-python<4.0.0 in d:\anaconda\lib\site-packages (from snowflake-sqlalchemy) (3.7.1)
# Requirement already satisfied: typing-extensions<5,>=4.3 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (4.10.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.4.0)
# Requirement already satisfied: tomlkit in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (0.11.1)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (23.0.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (22.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.4)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.5.1)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2023.3)
# Requirement already satisfied: pyjwt<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.4.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (39.0.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.15.1)
# Requirement already satisfied: requests<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2022.12.7)
# Requirement already satisfied: filelock<4,>=3.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.0.4)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy<2.0.0,>=1.4.0->snowflake-sqlalchemy) (2.0.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "snowflake-connector-python[pandas]"
# Out:
# Requirement already satisfied: snowflake-connector-python[pandas] in d:\anaconda\lib\site-packages (3.7.1)
# Requirement already satisfied: requests<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2.28.1)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2022.12.7)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (23.0.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (22.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (1.5.1)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (39.0.1)
# Requirement already satisfied: typing-extensions<5,>=4.3 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (4.10.0)
# Requirement already satisfied: filelock<4,>=3.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (3.9.0)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2023.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2.0.4)
# Requirement already satisfied: tomlkit in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (0.11.1)
# Requirement already satisfied: pyjwt<3.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (2.4.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (1.15.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (3.4)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (1.5.3)
# Requirement already satisfied: pyarrow in d:\anaconda\lib\site-packages (from snowflake-connector-python[pandas]) (15.0.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python[pandas]) (2.21)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\lib\site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0->snowflake-connector-python[pandas]) (1.26.14)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
conn = snowflake.connector.connect(
        user = 'admin',
        password = 'Admin@12345',
        ##password = getpass.getpass('Your Snowflake Password: '),
        ##password='Your password',
        ##  account = https://av68913.central-india.azure.snowflakecomputing.com
        account = 'av68913.central-india.azure',
        database='RETAILS',
        schema='PUBLIC',
        warehouse='DEMO_DWH',
  )

# %%
cur = conn.cursor()

# %%
select_demographic_RAW = 'SELECT * FROM DEMOGRAPHIC_RAM'

# %%
select_CAMPAIGN_DESC_RAW = 'SELECT * FROM CAMPAIGN_DESC_RAW'

# %%
select_CAMPAIGN_RAW = 'SELECT * FROM CAMPAIGN_RAW'

# %%
select_PRODUCT_RAW = 'SELECT * FROM PRODUCT_RAW'

# %%
select_COUPON_RAW = 'SELECT * FROM COUPON_RAW'

# %%
select_COUPON_REDEMPT_RAW = 'SELECT * FROM COUPON_REDEMPT_RAW'

# %%
select_TRANSACTION_RAW = 'SELECT * FROM TRANSACTION_RAW'

# %%
cur.execute(select_demographic_RAW)
demographic_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_CAMPAIGN_DESC_RAW)
CAMPAIGN_DESC_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_CAMPAIGN_RAW)
CAMPAIGN_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_PRODUCT_RAW)
PRODUCT_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_COUPON_RAW)
COUPON_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_COUPON_REDEMPT_RAW)
COUPON_REDEMPT_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_TRANSACTION_RAW)
TRANSACTION_RAW = cur.fetch_pandas_all()

# %%
cur.close()
# Out:
# True

# %%
conn.close()

# %%
demographic_RAW.head(5)
# Out:
#   AGE_DESC MARTIAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC      HH_COMP_DESC  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
#
#   HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  HOUSEHOLD_KEY
# 0                   2      None/Unknown              1
# 1                   2      None/Unknown              7
# 2                   3                 1              8
# 3                   4                 2             13
# 4                   1      None/Unknown             16

# %%
CAMPAIGN_DESC_RAW.head(5)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0       TypeB        24        659      719
# 1       TypeC        15        547      708
# 2       TypeB        25        659      691
# 3       TypeC        20        615      685
# 4       TypeB        23        646      684

# %%
CAMPAIGN_RAW.head(5)
# Out:
#   DESCRIPTION  HOUSEHOLD_KEY  CAMPAIGN
# 0       TypeA             17        26
# 1       TypeA             27        26
# 2       TypeA            212        26
# 3       TypeA            208        26
# 4       TypeA            192        26

# %%
PRODUCT_RAW.head(5)
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
COUPON_RAW.head(5)
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
COUPON_REDEMPT_RAW.head(5)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN
# 0              1  421  10000085364         8
# 1              1  421  51700010076         8
# 2              1  427  54200000033         8
# 3              1  597  10000085476        18
# 4              1  597  54200029176        18

# %%
TRANSACTION_RAW.head(5)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2056  29330027026  177     1106523         1         2.32
# 1           2056  29330027026  177     5567325         1         2.69
# 2           2056  29330027027  177     1106523         1         2.32
# 3           1873  29330097522  177     1135681         1         1.29
# 4           1602  29339301484  177      828427         1         0.22
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       341         0.00           4       26            0                  0
# 1       341         0.00           4       26            0                  0
# 2       341         0.00           4       26            0                  0
# 3       320         0.00           1       26            0                  0
# 4       334        -0.07        1537       26            0                  0

# %%
TRANSACTION_RAW.dtypes
# Out:
# HOUSEHOLD_KEY          int16
# BASKET_ID              int64
# DAY                    int16
# PRODUCT_ID             int32
# QUANTITY               int32
# SALES_VALUE          float64
# STORE_ID               int32
# RETAIL_DISC          float64
# TRANS_TIME             int16
# WEEK_NO                 int8
# COUPON_DISC             int8
# COUPON_MATCH_DISC       int8
# dtype: object

# %%
CAMPAIGN_DESC_RAW.shape
# Out:
# (30, 4)

# %%
COUPON_REDEMPT_RAW.shape
# Out:
# (2318, 4)

# %%
COUPON_RAW.shape
# Out:
# (124548, 3)

# %%
demographic_RAW.shape
# Out:
# (2500, 8)

# %%
PRODUCT_RAW.shape
# Out:
# (92353, 7)

# %%
TRANSACTION_RAW.shape
# Out:
# (3046148, 12)

# %%
CAMPAIGN_DESC_RAW.isnull().sum()
# Out:
# DESCRIPTION    0
# CAMPAIGN       0
# START_DAY      0
# END_DAY        0
# dtype: int64

# %%
CAMPAIGN_DESC_RAW.describe()
# Out:
#         CAMPAIGN   START_DAY     END_DAY
# count  30.000000   30.000000   30.000000
# mean   15.500000  463.866667  510.466667
# std     8.803408  134.488490  137.730555
# min     1.000000  224.000000  264.000000
# 25%     8.250000  360.000000  405.750000
# 50%    15.500000  470.000000  502.000000
# 75%    22.750000  584.000000  640.250000
# max    30.000000  659.000000  719.000000

# %%
PRODUCT_RAW.isnull().sum()
# Out:
# PRODUCT_ID              0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %%
PRODUCT_RAW.describe()
# Out:
#          PRODUCT_ID  MANUFACTURER
# count  9.235300e+04   92353.00000
# mean   5.328353e+06    1739.22833
# std    5.359937e+06    1818.26957
# min    2.567100e+04       1.00000
# 25%    9.706280e+05     328.00000
# 50%    1.621091e+06    1094.00000
# 75%    9.704770e+06    2264.00000
# max    1.831630e+07    6477.00000

# %%
demographic_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARTIAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
demographic_RAW.describe()
# Out:
#        HOUSEHOLD_KEY
# count     2500.00000
# mean      1250.50000
# std        721.83216
# min          1.00000
# 25%        625.75000
# 50%       1250.50000
# 75%       1875.25000
# max       2500.00000

# %%
COUPON_RAW.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
demographic_RAW.describe()
# Out:
#        HOUSEHOLD_KEY
# count     2500.00000
# mean      1250.50000
# std        721.83216
# min          1.00000
# 25%        625.75000
# 50%       1250.50000
# 75%       1875.25000
# max       2500.00000

# %%
COUPON_REDEMPT_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY    0
# DAY              0
# COUPON_UPC       0
# CAMPAIGN         0
# dtype: int64

# %%
COUPON_REDEMPT_RAW.describe()
# Out:
#        HOUSEHOLD_KEY          DAY    COUPON_UPC     CAMPAIGN
# count    2318.000000  2318.000000  2.318000e+03  2318.000000
# mean     1302.816652   528.217429  4.123049e+10    15.551337
# std       783.002545   100.360985  1.986068e+10     5.716636
# min         1.000000   225.000000  1.000009e+10     1.000000
# 25%       588.000000   458.250000  1.000009e+10    13.000000
# 50%      1396.500000   532.000000  5.234003e+10    14.000000
# 75%      2004.000000   605.000000  5.430002e+10    18.000000
# max      2500.000000   704.000000  5.897850e+10    30.000000

# %%
TRANSACTION_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# dtype: int64

# %%
TRANSACTION_RAW.describe()
# Out:
#        HOUSEHOLD_KEY     BASKET_ID           DAY    PRODUCT_ID      QUANTITY  \
# count   3.046148e+06  3.046148e+06  3.046148e+06  3.046148e+06  3.046148e+06
# mean    1.270120e+03  3.319450e+10  3.479035e+02  2.790596e+06  9.837236e+01
# std     7.263816e+02  4.790941e+09  2.013741e+02  3.702171e+06  1.139947e+03
# min     1.000000e+00  2.698485e+10  1.000000e+00  2.567100e+04  0.000000e+00
# 25%     6.530000e+02  2.909451e+10  1.590000e+02  9.163810e+05  1.000000e+00
# 50%     1.266000e+03  3.195643e+10  3.350000e+02  1.026699e+06  1.000000e+00
# 75%     1.914000e+03  3.557410e+10  5.240000e+02  1.130858e+06  1.000000e+00
# max     2.500000e+03  4.230536e+10  7.110000e+02  1.831630e+07  8.963800e+04
#
#         SALES_VALUE      STORE_ID   RETAIL_DISC    TRANS_TIME       WEEK_NO  \
# count  3.046148e+06  3.046148e+06  3.046148e+06  3.046148e+06  3.046148e+06
# mean   3.091450e+00  3.060459e+03 -5.407856e-01  1.564839e+03  5.038574e+01
# std    4.136374e+00  8.806566e+03  1.240165e+00  4.022114e+02  2.876700e+01
# min    0.000000e+00  1.000000e+00 -1.800000e+02  0.000000e+00  1.000000e+00
# 25%    1.290000e+00  3.300000e+02 -6.900000e-01  1.309000e+03  2.300000e+01
# 50%    2.000000e+00  3.700000e+02 -3.000000e-02  1.615000e+03  4.900000e+01
# 75%    3.490000e+00  4.220000e+02  0.000000e+00  1.847000e+03  7.600000e+01
# max    8.400000e+02  3.428000e+04  3.990000e+00  2.359000e+03  1.020000e+02
#
#         COUPON_DISC  COUPON_MATCH_DISC
# count  3.046148e+06       3.046148e+06
# mean  -1.756251e-02      -2.481166e-03
# std    2.231829e-01       5.121909e-02
# min   -5.600000e+01      -8.000000e+00
# 25%    0.000000e+00       0.000000e+00
# 50%    0.000000e+00       0.000000e+00
# 75%    0.000000e+00       0.000000e+00
# max    0.000000e+00       0.000000e+00

# %% [markdown]
# #### Date Modifications

# %%
from datetime import datetime,timedelta

# %%
import pandas as pd

# %%
start_date = pd.to_datetime('2020-01-01')

# %%
start_date
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
TRANSACTION_RAW.head(20)
# Out:
#     HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0            2056  29330027026  177     1106523         1         2.32
# 1            2056  29330027026  177     5567325         1         2.69
# 2            2056  29330027027  177     1106523         1         2.32
# 3            1873  29330097522  177     1135681         1         1.29
# 4            1602  29339301484  177      828427         1         0.22
# 5            1602  29339301484  177      844740         2         2.50
# 6            1602  29339301484  177      847302         1         0.99
# 7            1602  29339301484  177      849202         1         7.79
# 8            1602  29339301484  177      856382         1         2.59
# 9            1602  29339301484  177      858893         1         1.39
# 10           1602  29339301484  177      875694         2         1.98
# 11           1602  29339301484  177      878026         1         1.09
# 12           1602  29339301484  177      891520         1         1.39
# 13           1602  29339301484  177      898480         1         2.19
# 14           1602  29339301484  177      924423         1         1.19
# 15           1602  29339301484  177      935284         2         2.00
# 16           1602  29339301484  177      952925         1         0.22
# 17           1602  29339301484  177      953561         1         2.94
# 18           1602  29339301484  177      993639         1         1.39
# 19           1602  29339301484  177     1006483         1         2.81
#
#     STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0        341         0.00           4       26            0                  0
# 1        341         0.00           4       26            0                  0
# 2        341         0.00           4       26            0                  0
# 3        320         0.00           1       26            0                  0
# 4        334        -0.07        1537       26            0                  0
# 5        334        -0.68        1537       26            0                  0
# 6        334        -0.50        1537       26            0                  0
# 7        334         0.00        1537       26            0                  0
# 8        334         0.00        1537       26            0                  0
# 9        334         0.00        1537       26            0                  0
# 10       334        -0.40        1537       26            0                  0
# 11       334         0.00        1537       26            0                  0
# 12       334         0.00        1537       26            0                  0
# 13       334         0.00        1537       26            0                  0
# 14       334         0.00        1537       26            0                  0
# 15       334         0.00        1537       26            0                  0
# 16       334        -0.07        1537       26            0                  0
# 17       334        -0.73        1537       26            0                  0
# 18       334         0.00        1537       26            0                  0
# 19       334         0.00        1537       26            0                  0

# %%
TRANSACTION_RAW['Date'] = start_date + pd.to_timedelta(TRANSACTION_RAW['DAY'],unit='D')

# %%
TRANSACTION_RAW['Date'].head(20)
# Out:
# 0    2020-06-26
# 1    2020-06-26
# 2    2020-06-26
# 3    2020-06-26
# 4    2020-06-26
# 5    2020-06-26
# 6    2020-06-26
# 7    2020-06-26
# 8    2020-06-26
# 9    2020-06-26
# 10   2020-06-26
# 11   2020-06-26
# 12   2020-06-26
# 13   2020-06-26
# 14   2020-06-26
# 15   2020-06-26
# 16   2020-06-26
# 17   2020-06-26
# 18   2020-06-26
# 19   2020-06-26
# Name: Date, dtype: datetime64[ns]

# %%
CAMPAIGN_DESC_RAW['Start_date']= start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['START_DAY'],unit='D')

# %%
CAMPAIGN_DESC_RAW['End_date']=start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['END_DAY'],unit='D')

# %%
CAMPAIGN_DESC_RAW.head(10)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
# 4       TypeB        23        646      684 2021-10-08 2021-11-15
# 5       TypeB        21        624      656 2021-09-16 2021-10-18
# 6       TypeB        22        624      656 2021-09-16 2021-10-18
# 7       TypeA        18        587      642 2021-08-10 2021-10-04
# 8       TypeB        19        603      635 2021-08-26 2021-09-27
# 9       TypeB        17        575      607 2021-07-29 2021-08-30

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'] = CAMPAIGN_DESC_RAW['END_DAY'] - CAMPAIGN_DESC_RAW['START_DAY']

# %%
CAMPAIGN_DESC_RAW.head(20)
# Out:
#    DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0        TypeB        24        659      719 2021-10-21 2021-12-20
# 1        TypeC        15        547      708 2021-07-01 2021-12-09
# 2        TypeB        25        659      691 2021-10-21 2021-11-22
# 3        TypeC        20        615      685 2021-09-07 2021-11-16
# 4        TypeB        23        646      684 2021-10-08 2021-11-15
# 5        TypeB        21        624      656 2021-09-16 2021-10-18
# 6        TypeB        22        624      656 2021-09-16 2021-10-18
# 7        TypeA        18        587      642 2021-08-10 2021-10-04
# 8        TypeB        19        603      635 2021-08-26 2021-09-27
# 9        TypeB        17        575      607 2021-07-29 2021-08-30
# 10       TypeC        14        531      596 2021-06-15 2021-08-19
# 11       TypeB        16        561      593 2021-07-15 2021-08-16
# 12       TypeA        13        504      551 2021-05-19 2021-07-05
# 13       TypeB        11        477      523 2021-04-22 2021-06-07
# 14       TypeB        12        477      509 2021-04-22 2021-05-24
# 15       TypeB        10        463      495 2021-04-08 2021-05-10
# 16       TypeB         9        435      467 2021-03-11 2021-04-12
# 17       TypeA         8        412      460 2021-02-16 2021-04-05
# 18       TypeB         7        398      432 2021-02-02 2021-03-08
# 19       TypeC         6        393      425 2021-01-28 2021-03-01
#
#     Campaign_Duration
# 0                  60
# 1                 161
# 2                  32
# 3                  70
# 4                  38
# 5                  32
# 6                  32
# 7                  55
# 8                  32
# 9                  32
# 10                 65
# 11                 32
# 12                 47
# 13                 46
# 14                 32
# 15                 32
# 16                 32
# 17                 48
# 18                 34
# 19                 32

# %%
COUPON_REDEMPT_RAW['Date'] = start_date + pd.to_timedelta(COUPON_REDEMPT_RAW['DAY'],unit='D')

# %%
COUPON_REDEMPT_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN       Date
# 0              1  421  10000085364         8 2021-02-25
# 1              1  421  51700010076         8 2021-02-25
# 2              1  427  54200000033         8 2021-03-03
# 3              1  597  10000085476        18 2021-08-20
# 4              1  597  54200029176        18 2021-08-20
# 5              8  422  53600000078         8 2021-02-26
# 6             13  396  53700048182         5 2021-01-31
# 7             13  424  10000085364         8 2021-02-28
# 8             13  434  53600000078         8 2021-03-10
# 9             13  447  52370020076         8 2021-03-23

# %%
TRANSACTION_RAW['Date'].max()
# Out:
# Timestamp('2021-12-12 00:00:00')

# %%
CAMPAIGN_DESC_RAW['End_date'].max()
# Out:
# Timestamp('2021-12-20 00:00:00')

# %%
COUPON_REDEMPT_RAW['Date'].max()
# Out:
# Timestamp('2021-12-05 00:00:00')

# %% [markdown]
# #### Understanding the Dataset

# %%
demographic_RAW.shape
# Out:
# (2500, 8)

# %%
demographic_RAW.columns
# Out:
# Index(['AGE_DESC', 'MARTIAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC',
#        'HH_COMP_DESC', 'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC',
#        'HOUSEHOLD_KEY'],
#       dtype='object')

# %%
demographic_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARTIAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
demographic_RAW.dtypes
# Out:
# AGE_DESC               object
# MARTIAL_STATUS_CODE    object
# INCOME_DESC            object
# HOMEOWNER_DESC         object
# HH_COMP_DESC           object
# HOUSEHOLD_SIZE_DESC    object
# KID_CATEGORY_DESC      object
# HOUSEHOLD_KEY           int16
# dtype: object

# %%
demographic_RAW['AGE_DESC'].value_counts()
# Out:
# 45-54    901
# 35-44    594
# 25-34    445
# 65+      230
# 55-64    187
# 19-24    143
# Name: AGE_DESC, dtype: int64

# %%
demographic_RAW['HOUSEHOLD_SIZE_DESC'].value_counts()
# Out:
# 2     1004
# 1      783
# 3      338
# 5+     206
# 4      169
# Name: HOUSEHOLD_SIZE_DESC, dtype: int64

# %%
CAMPAIGN_DESC_RAW.shape
# Out:
# (30, 7)

# %%
CAMPAIGN_DESC_RAW.isnull().sum()
# Out:
# DESCRIPTION          0
# CAMPAIGN             0
# START_DAY            0
# END_DAY              0
# Start_date           0
# End_date             0
# Campaign_Duration    0
# dtype: int64

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# dtype: object

# %%
CAMPAIGN_DESC_RAW.head(4)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
#
#    Campaign_Duration
# 0                 60
# 1                161
# 2                 32
# 3                 70

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'].mean()
# Out:
# 46.6

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# dtype: object

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='CAMPAIGN',y='Campaign_Duration',data = CAMPAIGN_DESC_RAW)
# Out:
# <Axes: xlabel='CAMPAIGN', ylabel='Campaign_Duration'>

# %%
CAMPAIGN_DESC_RAW.groupby('DESCRIPTION').aggregate({'CAMPAIGN':'count','Campaign_Duration':'mean'})
# Out:
#              CAMPAIGN  Campaign_Duration
# DESCRIPTION
# TypeA               5          47.200000
# TypeB              19          37.631579
# TypeC               6          74.500000

# %%
CAMPAIGN_DESC_RAW['Start_month'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['End_month'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['Start_Year'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW['End_Year'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW.head(4)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
#
#    Campaign_Duration Start_month End_month Start_Year End_Year
# 0                 60          10        12       2021     2021
# 1                161          07        12       2021     2021
# 2                 32          10        11       2021     2021
# 3                 70          09        11       2021     2021

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# Start_month                  object
# End_month                    object
# Start_Year                   object
# End_Year                     object
# dtype: object

# %%
CAMPAIGN_RAW.shape
# Out:
# (7208, 3)

# %%
CAMPAIGN_RAW.columns
# Out:
# Index(['DESCRIPTION', 'HOUSEHOLD_KEY', 'CAMPAIGN'], dtype='object')

# %%
CAMPAIGN_RAW.isnull().sum()
# Out:
# DESCRIPTION      0
# HOUSEHOLD_KEY    0
# CAMPAIGN         0
# dtype: int64

# %%
CAMPAIGN_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 1584

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2500

# %% [markdown]
# #### There are 1584 households have participed to the campaign, leaving 916 households who never participated to any campaign.

# %%
CAMPAIGN_RAW.dtypes
# Out:
# DESCRIPTION      object
# HOUSEHOLD_KEY     int16
# CAMPAIGN           int8
# dtype: object

# %%
CAMPAIGN_RAW.groupby('HOUSEHOLD_KEY')['CAMPAIGN'].count()
# Out:
# HOUSEHOLD_KEY
# 1       8
# 2       1
# 3       3
# 4       1
# 6       4
#        ..
# 2496    5
# 2497    3
# 2498    6
# 2499    2
# 2500    8
# Name: CAMPAIGN, Length: 1584, dtype: int64

# %%
plt.figure(figsize=(15,5))
CAMPAIGN_RAW.groupby('CAMPAIGN')['HOUSEHOLD_KEY'].count().plot.bar()
plt.ylabel('Number of Households Reached To')
# Out:
# Text(0, 0.5, 'Number of Households Reached To')

# %% [markdown]
# #### In Campaing 18 maximum number of households are participated.

# %%
COUPON_RAW.shape
# Out:
# (124548, 3)

# %%
COUPON_RAW.columns
# Out:
# Index(['COUPON_UPC', 'PRODUCT_ID', 'CAMPAIGN'], dtype='object')

# %%
COUPON_RAW['COUPON_UPC'].nunique()
# Out:
# 1135

# %%
COUPON_RAW.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
COUPON_RAW.dtypes
# Out:
# COUPON_UPC    int64
# PRODUCT_ID    int32
# CAMPAIGN       int8
# dtype: object

# %%
Coupon_Given=COUPON_RAW.groupby("CAMPAIGN").aggregate(Total_product = ('PRODUCT_ID','nunique'),
                                                    Total_Coupon_Given = ('COUPON_UPC','nunique'))

# %%
Coupon_Given.sort_values(by='Total_product',ascending=False).head(10)
# Out:
#           Total_product  Total_Coupon_Given
# CAMPAIGN
# 13                35616                 207
# 18                35513                 209
# 8                 17178                 209
# 26                 3396                 181
# 30                 3205                 181
# 22                 1917                  21
# 24                 1887                   2
# 16                 1025                  13
# 25                  826                  17
# 9                   825                  18

# %%
Coupon_Given.head(10)
# Out:
#           Total_product  Total_Coupon_Given
# CAMPAIGN
# 1                   383                  11
# 2                   301                  16
# 3                   506                  34
# 4                   200                  12
# 5                   443                  11
# 6                    18                   1
# 7                   259                   8
# 8                 17178                 209
# 9                   825                  18
# 10                  393                  14

# %%
Coupon_Given = Coupon_Given.merge(right = CAMPAIGN_DESC_RAW,on='CAMPAIGN',how='left')

# %%
Coupon_Given.head(10)
# Out:
#    CAMPAIGN  Total_product  Total_Coupon_Given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
# 5         6             18                   1       TypeC        393
# 6         7            259                   8       TypeB        398
# 7         8          17178                 209       TypeA        412
# 8         9            825                  18       TypeB        435
# 9        10            393                  14       TypeB        463
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_month End_month  \
# 0      383 2020-12-12 2021-01-18                 37          12        01
# 1      383 2020-12-17 2021-01-18                 32          12        01
# 2      412 2020-12-22 2021-02-16                 56          12        02
# 3      404 2021-01-07 2021-02-08                 32          01        02
# 4      411 2021-01-12 2021-02-15                 34          01        02
# 5      425 2021-01-28 2021-03-01                 32          01        03
# 6      432 2021-02-02 2021-03-08                 34          02        03
# 7      460 2021-02-16 2021-04-05                 48          02        04
# 8      467 2021-03-11 2021-04-12                 32          03        04
# 9      495 2021-04-08 2021-05-10                 32          04        05
#
#   Start_Year End_Year
# 0       2020     2021
# 1       2020     2021
# 2       2020     2021
# 3       2021     2021
# 4       2021     2021
# 5       2021     2021
# 6       2021     2021
# 7       2021     2021
# 8       2021     2021
# 9       2021     2021

# %%
Coupon_Given.columns
# Out:
# Index(['CAMPAIGN', 'Total_product', 'Total_Coupon_Given', 'DESCRIPTION',
#        'START_DAY', 'END_DAY', 'Start_date', 'End_date', 'Campaign_Duration',
#        'Start_month', 'End_month', 'Start_Year', 'End_Year'],
#       dtype='object')

# %%
Coupon_Given.loc[:,('CAMPAIGN','Total_product','Total_Coupon_Given','Start_Year','End_Year','Start_month','End_month','DESCRIPTION','Campaign_Duration')].sort_values(by='Total_product',
                    ascending=False).head(10)
# Out:
#     CAMPAIGN  Total_product  Total_Coupon_Given Start_Year End_Year  \
# 12        13          35616                 207       2021     2021
# 17        18          35513                 209       2021     2021
# 7          8          17178                 209       2021     2021
# 25        26           3396                 181       2020     2020
# 29        30           3205                 181       2020     2021
# 21        22           1917                  21       2021     2021
# 23        24           1887                   2       2021     2021
# 15        16           1025                  13       2021     2021
# 24        25            826                  17       2021     2021
# 8          9            825                  18       2021     2021
#
#    Start_month End_month DESCRIPTION  Campaign_Duration
# 12          05        07       TypeA                 47
# 17          08        10       TypeA                 55
# 7           02        04       TypeA                 48
# 25          08        09       TypeA                 40
# 29          11        01       TypeA                 46
# 21          09        10       TypeB                 32
# 23          10        12       TypeB                 60
# 15          07        08       TypeB                 32
# 24          10        11       TypeB                 32
# 8           03        04       TypeB                 32

# %%
COUPON_RAW.head()
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
PRODUCT_RAW.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
coupon_product = COUPON_RAW.merge(right=PRODUCT_RAW,on='PRODUCT_ID',how='left')

# %%
coupon_product.head(5)
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN  MANUFACTURER DEPARTMENT     BRAND  \
# 0  10000089061       27160         4            69    GROCERY   Private
# 1  10000089064       27754         9            69    GROCERY   Private
# 2  10000089073       28897        12            69    GROCERY   Private
# 3  51800009050       28919        28           236    GROCERY  National
# 4  52100000076       28929        25           317    GROCERY  National
#
#              COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 0            SHORTENING/OIL             VEGETABLE/SALAD OIL
# 1    FRZN VEGETABLE/VEG DSH  FRZN BAGGED VEGETABLES - PLAIN
# 2                      EGGS                  EGGS - X-LARGE
# 3  REFRGRATD DOUGH PRODUCTS       REFRIGERATED COOKIES-CHUB
# 4                    CHEESE                   STRING CHEESE
#
#   CURR_SIZE_OF_PRODUCT
# 0                48 OZ
# 1                16 OZ
# 2           A D   1 DZ
# 3              16.5 OZ
# 4           AB    8 OZ

# %%
coupon_product.isnull().sum()
# Out:
# COUPON_UPC              0
# PRODUCT_ID              0
# CAMPAIGN                0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %% [markdown]
# #### Top 10 product on which the Coupon has been applied

# %%
coupon_product['COMMODITY_DESC'].value_counts().head(10)
# Out:
# HAIR CARE PRODUCTS        6261
# MAKEUP AND TREATMENT      5585
# FRZN MEAT/MEAT DINNERS    4893
# FROZEN PIZZA              3658
# BEEF                      3314
# ICE CREAM/MILK/SHERBTS    3257
# CHEESE                    3146
# YOGURT                    2460
# ORAL HYGIENE PRODUCTS     2437
# LUNCHMEAT                 2425
# Name: COMMODITY_DESC, dtype: int64

# %%
COUPON_REDEMPT_RAW.shape
# Out:
# (2318, 5)

# %%
COUPON_REDEMPT_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'DAY', 'COUPON_UPC', 'CAMPAIGN', 'Date'], dtype='object')

# %%
COUPON_REDEMPT_RAW['COUPON_UPC'].nunique()
# Out:
# 556

# %%
COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique')).sort_values(by='total_coupon_reedm',ascending=False).plot.bar()
# Out:
# <Axes: xlabel='CAMPAIGN'>

# %%
Coupon_redeem = COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique'))

# %%
Coupon_redeem.sort_values(by = 'total_coupon_reedm',ascending=False)
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 13                       129
# 18                       121
# 8                        105
# 26                        53
# 30                        41
# 29                        17
# 23                        16
# 25                        15
# 20                        15
# 9                         14
# 14                        14
# 17                        13
# 22                        12
# 12                        11
# 16                        10
# 19                         9
# 10                         7
# 11                         6
# 4                          6
# 21                         5
# 7                          5
# 5                          5
# 2                          4
# 15                         2
# 24                         2
# 3                          2
# 6                          1
# 27                         1
# 28                         1
# 1                          1

# %%
Coupon_Given.head()
# Out:
#    CAMPAIGN  Total_product  Total_Coupon_Given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_month End_month  \
# 0      383 2020-12-12 2021-01-18                 37          12        01
# 1      383 2020-12-17 2021-01-18                 32          12        01
# 2      412 2020-12-22 2021-02-16                 56          12        02
# 3      404 2021-01-07 2021-02-08                 32          01        02
# 4      411 2021-01-12 2021-02-15                 34          01        02
#
#   Start_Year End_Year
# 0       2020     2021
# 1       2020     2021
# 2       2020     2021
# 3       2021     2021
# 4       2021     2021

# %%
Coupon_redeem.head(3)
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 1                          1
# 2                          4
# 3                          2

# %%
Coupon_redeem = Coupon_redeem.merge(right = Coupon_Given,on='CAMPAIGN',how='left')

# %%
Coupon_redeem.head()
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_product  Total_Coupon_Given  \
# 0         1                   1            383                  11
# 1         2                   4            301                  16
# 2         3                   2            506                  34
# 3         4                   6            200                  12
# 4         5                   5            443                  11
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 0       TypeB        346      383 2020-12-12 2021-01-18                 37
# 1       TypeB        351      383 2020-12-17 2021-01-18                 32
# 2       TypeC        356      412 2020-12-22 2021-02-16                 56
# 3       TypeB        372      404 2021-01-07 2021-02-08                 32
# 4       TypeB        377      411 2021-01-12 2021-02-15                 34
#
#   Start_month End_month Start_Year End_Year
# 0          12        01       2020     2021
# 1          12        01       2020     2021
# 2          12        02       2020     2021
# 3          01        02       2021     2021
# 4          01        02       2021     2021

# %%
Coupon_redeem['Coupon_redeem_rate']=(Coupon_redeem['total_coupon_reedm']/Coupon_redeem['Total_Coupon_Given'])*100

# %%
Coupon_redeem.head().sort_values(by = 'Coupon_redeem_rate',ascending = False)
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_product  Total_Coupon_Given  \
# 3         4                   6            200                  12
# 4         5                   5            443                  11
# 1         2                   4            301                  16
# 0         1                   1            383                  11
# 2         3                   2            506                  34
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 3       TypeB        372      404 2021-01-07 2021-02-08                 32
# 4       TypeB        377      411 2021-01-12 2021-02-15                 34
# 1       TypeB        351      383 2020-12-17 2021-01-18                 32
# 0       TypeB        346      383 2020-12-12 2021-01-18                 37
# 2       TypeC        356      412 2020-12-22 2021-02-16                 56
#
#   Start_month End_month Start_Year End_Year  Coupon_redeem_rate
# 3          01        02       2021     2021           50.000000
# 4          01        02       2021     2021           45.454545
# 1          12        01       2020     2021           25.000000
# 0          12        01       2020     2021            9.090909
# 2          12        02       2020     2021            5.882353

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='CAMPAIGN',y='Coupon_redeem_rate',data=Coupon_redeem)
# Out:
# <Axes: xlabel='CAMPAIGN', ylabel='Coupon_redeem_rate'>

# %%
TRANSACTION_RAW.shape
# Out:
# (3046148, 13)

# %%
TRANSACTION_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'BASKET_ID', 'DAY', 'PRODUCT_ID', 'QUANTITY',
#        'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'TRANS_TIME', 'WEEK_NO',
#        'COUPON_DISC', 'COUPON_MATCH_DISC', 'Date'],
#       dtype='object')

# %%
TRANSACTION_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# Date                 0
# dtype: int64

# %%
TRANSACTION_RAW['BASKET_ID'].count()
# Out:
# 3046148

# %%
TRANSACTION_RAW['BASKET_ID'].nunique()
# Out:
# 276484

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2500

# %%
trnx_bucket =TRANSACTION_RAW.groupby('BASKET_ID').aggregate({'SALES_VALUE':'sum','COUPON_DISC':'sum','COUPON_MATCH_DISC':'sum'})

# %%
trnx_bucket.head()
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC
# BASKET_ID
# 26984851472        11.82            0                  0
# 26984851516        24.86            0                  0
# 26984896261        22.74            0                  0
# 26984905972         5.10            0                  0
# 26984945254         7.06            0                  0

# %%
trnx_bucket['Use_coupon'] = trnx_bucket['COUPON_DISC']!=0

# %%
trnx_bucket['Use_coupon'].value_counts()
# Out:
# False    260812
# True      15672
# Name: Use_coupon, dtype: int64

# %%
trnx_bucket.sort_values('SALES_VALUE',ascending=False).head(10)
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC  Use_coupon
# BASKET_ID
# 32006114302       961.49            0                  0       False
# 27534431747       931.40           -6                 -2        True
# 27798435271       926.34           -4                 -4        True
# 27093315740       801.58            0                  0       False
# 28941937397       801.12           -2                  0        True
# 28210676830       782.10            0                  0       False
# 27950470466       752.76           -4                  0        True
# 29034966796       738.96            0                  0       False
# 28919755135       737.90            0                  0       False
# 28675556859       731.72           -6                  0        True

# %%
round(trnx_bucket['SALES_VALUE'].mean(),2)
# Out:
# 34.06

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x=trnx_bucket['SALES_VALUE'])
plt.title('Basket value boxplot', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Basket value boxplot')

# %%
trnx_bucket.groupby('Use_coupon').aggregate( sales_mean=('SALES_VALUE','mean'),
                                             COUPON_DISC_mean =('COUPON_DISC','mean'),
                                             COUPON_MATCH_DISC=('COUPON_MATCH_DISC','mean'),
                                             No_coupon  =('SALES_VALUE','count'))
# Out:
#             sales_mean  COUPON_DISC_mean  COUPON_MATCH_DISC  No_coupon
# Use_coupon
# False        31.387516          0.000000          -0.000019     260812
# True         78.533305         -3.413604          -0.481942      15672

# %% [markdown]
# The average basket value without a coupon is $26.79.
#
# The average basket value with a coupon is $68.21.
#
# The average discount generated by coupons is $2.98.
#
# #### It shows that customeer purchase more product when coupon is given to them

# %%
trnx_desc = TRANSACTION_RAW.merge(right= trnx_bucket,on='BASKET_ID',how='left')

# %%
trnx_desc.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2056  29330027026  177     1106523         1           2.32
# 1           2056  29330027026  177     5567325         1           2.69
# 2           2056  29330027027  177     1106523         1           2.32
# 3           1873  29330097522  177     1135681         1           1.29
# 4           1602  29339301484  177      828427         1           0.22
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       341         0.00           4       26              0
# 1       341         0.00           4       26              0
# 2       341         0.00           4       26              0
# 3       320         0.00           1       26              0
# 4       334        -0.07        1537       26              0
#
#    COUPON_MATCH_DISC_x       Date  SALES_VALUE_y  COUPON_DISC_y  \
# 0                    0 2020-06-26           5.01              0
# 1                    0 2020-06-26           5.01              0
# 2                    0 2020-06-26           2.32              0
# 3                    0 2020-06-26           1.29              0
# 4                    0 2020-06-26         101.20              0
#
#    COUPON_MATCH_DISC_y  Use_coupon
# 0                    0       False
# 1                    0       False
# 2                    0       False
# 3                    0       False
# 4                    0       False

# %%
trnx_desc= trnx_desc.merge(right=PRODUCT_RAW,on='PRODUCT_ID',how='left')

# %%
trnx_desc.head(3)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2056  29330027026  177     1106523         1           2.32
# 1           2056  29330027026  177     5567325         1           2.69
# 2           2056  29330027027  177     1106523         1           2.32
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  ...  SALES_VALUE_y  \
# 0       341          0.0           4       26  ...           5.01
# 1       341          0.0           4       26  ...           5.01
# 2       341          0.0           4       26  ...           2.32
#
#    COUPON_DISC_y COUPON_MATCH_DISC_y  Use_coupon  MANUFACTURER  DEPARTMENT  \
# 0              0                   0       False            69     GROCERY
# 1              0                   0       False           531     GROCERY
# 2              0                   0       False            69     GROCERY
#
#       BRAND       COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 0   Private  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 1  National        CANNED JUICES  BLENDED JUICE&COMBINATIONS (50
# 2   Private  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
#
#   CURR_SIZE_OF_PRODUCT
# 0                 1 GA
# 1                46 OZ
# 2                 1 GA
#
# [3 rows x 23 columns]

# %%
trnx_desc.drop(['SALES_VALUE_y','COUPON_DISC_y','COUPON_MATCH_DISC_y'],axis=1,inplace=True)

# %%
trnx_desc.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2056  29330027026  177     1106523         1           2.32
# 1           2056  29330027026  177     5567325         1           2.69
# 2           2056  29330027027  177     1106523         1           2.32
# 3           1873  29330097522  177     1135681         1           1.29
# 4           1602  29339301484  177      828427         1           0.22
# 5           1602  29339301484  177      844740         2           2.50
# 6           1602  29339301484  177      847302         1           0.99
# 7           1602  29339301484  177      849202         1           7.79
# 8           1602  29339301484  177      856382         1           2.59
# 9           1602  29339301484  177      858893         1           1.39
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       341         0.00           4       26              0
# 1       341         0.00           4       26              0
# 2       341         0.00           4       26              0
# 3       320         0.00           1       26              0
# 4       334        -0.07        1537       26              0
# 5       334        -0.68        1537       26              0
# 6       334        -0.50        1537       26              0
# 7       334         0.00        1537       26              0
# 8       334         0.00        1537       26              0
# 9       334         0.00        1537       26              0
#
#    COUPON_MATCH_DISC_x       Date  Use_coupon  MANUFACTURER DEPARTMENT  \
# 0                    0 2020-06-26       False            69    GROCERY
# 1                    0 2020-06-26       False           531    GROCERY
# 2                    0 2020-06-26       False            69    GROCERY
# 3                    0 2020-06-26       False          1600    DRUG GM
# 4                    0 2020-06-26       False            69    GROCERY
# 5                    0 2020-06-26       False          2515    GROCERY
# 6                    0 2020-06-26       False            69    GROCERY
# 7                    0 2020-06-26       False           239    GROCERY
# 8                    0 2020-06-26       False           194    GROCERY
# 9                    0 2020-06-26       False           869    GROCERY
#
#       BRAND          COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 0   Private     FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 1  National           CANNED JUICES  BLENDED JUICE&COMBINATIONS (50
# 2   Private     FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 3  National              BABY FOODS              BABY SPRING WATERS
# 4   Private                CAT FOOD  CANNED CAT FOOD (9 LIVES/FRISK
# 5  National  SEAFOOD - SHELF STABLE                            TUNA
# 6   Private       DRY NOODLES/PASTA                   SPAGHETTI DRY
# 7  National              BEERS/ALES             BEERALEMALT LIQUORS
# 8  National          DINNER MXS:DRY                 SKILLET DINNERS
# 9  National  DRY BN/VEG/POTATO/RICE          NOODLE SIDE DISH MIXES
#
#   CURR_SIZE_OF_PRODUCT
# 0                 1 GA
# 1                46 OZ
# 2                 1 GA
# 3
# 4               5.5 OZ
# 5                 6 OZ
# 6                16 OZ
# 7                12 OZ
# 8               8.4 OZ
# 9               4.4 OZ

# %%
COMMODITY_Coupon = trnx_desc.groupby('COMMODITY_DESC').aggregate(total_quantity=('QUANTITY','count'),
                                             Use_coupon=('Use_coupon','sum'),
                                             Coupon=('COUPON_DISC_x','sum'))

# %%
COMMODITY_Coupon.head(10)
# Out:
#                       total_quantity  Use_coupon  Coupon
# COMMODITY_DESC
#                                 9142        6891  -11992
# (CORP USE ONLY)                   73           5       0
# ADULT INCONTINENCE               627          90     -38
# AIR CARE                        6484        1513   -1053
# ANALGESICS                      5450         781     -16
# ANTACIDS                        2196         316     -29
# APPAREL                          648          70      -1
# APPLES                         16441        2496       0
# AUDIO/VIDEO PRODUCTS            1222         141     -86
# AUTOMOTIVE PRODUCTS             1284         111     -13

# %%
COMMODITY_Coupon['Coupon%']=round((COMMODITY_Coupon['Use_coupon']/COMMODITY_Coupon['total_quantity'])*100,2)

# %%
COMMODITY_Coupon.sort_values('Coupon%',ascending=False).head(30)
# Out:
#                                 total_quantity  Use_coupon  Coupon  Coupon%
# COMMODITY_DESC
#                                           9142        6891  -11992    75.38
# BABY FOODS                               24020        6762    -387    28.15
# DIAPERS & DISPOSABLES                     5872        1447   -1325    24.64
# AIR CARE                                  6484        1513   -1053    23.33
# RESTRICTED DIET                             56          13       0    23.21
# BULK FOODS                                   9           2       0    22.22
# BABY HBC                                  5443        1201    -407    22.07
# FRZN SEAFOOD                                73          16       0    21.92
# FRZN BREAKFAST FOODS                     12338        2633    -482    21.34
# FROZEN - BOXED(GROCERY)                   1098         230     -54    20.95
# HOUSEHOLD CLEANG NEEDS                   12422        2576    -761    20.74
# CAT LITTER                                3803         769    -213    20.22
# RICE CAKES                                1872         375      -6    20.03
# VITAMINS                                  2760         550    -229    19.93
# LAUNDRY ADDITIVES                         5900        1169    -173    19.81
# REFRGRATD DOUGH PRODUCTS                 21599        4265    -989    19.75
# FACIAL TISS/DNR NAPKIN                    9037        1769    -159    19.58
# FROZEN BREAD/DOUGH                        9153        1781    -494    19.46
# FRUIT - SHELF STABLE                     24803        4786    -191    19.30
# PICKLE/RELISH/PKLD VEG                    8421        1613    -420    19.15
# DOG FOODS                                14016        2677    -850    19.10
# CONVENIENT BRKFST/WHLSM SNACKS           26425        4996    -698    18.91
# DISHWASH DETERGENTS                       8140        1536    -367    18.87
# FRZN VEGETABLE/VEG DSH                   25645        4747    -260    18.51
# ORAL HYGIENE PRODUCTS                    12039        2190    -763    18.19
# HAND/BODY/FACIAL PRODUCTS                 3974         721    -210    18.14
# CAT FOOD                                 18854        3416    -485    18.12
# FD WRAPS/BAGS/TRSH BG                    16503        2989    -381    18.11
# MOLASSES/SYRUP/PANCAKE MIXS               6388        1122    -109    17.56
# SMOKING CESSATIONS                          97          17       0    17.53

# %% [markdown]
# #### While the most prominents products for which coupons are created are haircare and makeup products, coupons are mostly used on drinks, cigarettes, diapers, etc. Bathroom products are not even among the top 10

# %%
TRANSACTION_RAW.groupby(['HOUSEHOLD_KEY','WEEK_NO','DAY']).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                                  'COUPON_DISC' :'sum','COUPON_MATCH_DISC':'sum'})
# Out:
#                            SALES_VALUE  RETAIL_DISC  COUPON_DISC  \
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51        157.32       -33.08           -2
#               10      67         82.20       -17.18            0
#               13      88         53.80       -13.44            0
#               14      94        126.86       -22.16           -4
#               15      101       106.90       -32.84            0
# ...                                ...          ...          ...
# 2500          100     695        57.68       -14.85           -2
#                       698        50.54       -14.72           -2
#               101     704        73.65       -19.79           -2
#               102     706        13.95        -0.42            0
#                       708        45.12       -15.99           -1
#
#                            COUPON_MATCH_DISC
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51                   0
#               10      67                   0
#               13      88                   0
#               14      94                  -2
#               15      101                  0
# ...                                      ...
# 2500          100     695                  0
#                       698                  0
#               101     704                  0
#               102     706                  0
#                       708                  0
#
# [225533 rows x 4 columns]

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2056  29330027026  177     1106523         1         2.32
# 1           2056  29330027026  177     5567325         1         2.69
# 2           2056  29330027027  177     1106523         1         2.32
# 3           1873  29330097522  177     1135681         1         1.29
# 4           1602  29339301484  177      828427         1         0.22
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0       341         0.00           4       26            0                  0
# 1       341         0.00           4       26            0                  0
# 2       341         0.00           4       26            0                  0
# 3       320         0.00           1       26            0                  0
# 4       334        -0.07        1537       26            0                  0
#
#         Date
# 0 2020-06-26
# 1 2020-06-26
# 2 2020-06-26
# 3 2020-06-26
# 4 2020-06-26

# %%
TRANSACTION_RAW.groupby(TRANSACTION_RAW['Date'].dt.year).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                                   'COUPON_DISC':'sum'})
# Out:
#       SALES_VALUE  RETAIL_DISC  COUPON_DISC
# Date
# 2020   5005454.47   -890441.19       -25549
# 2021   4411560.34   -756871.76       -27949

# %% [markdown]
# #### Sales Value increases as Retail Discount and Coupon Discount increases
#
# #### Droping the columns

# %%
from datetime import datetime

# %%
CAMPAIGN_DESC_RAW.drop(['START_DAY','END_DAY'],axis=1,inplace=True)

# %%
CAMPAIGN_DESC_RAW.head(3)
# Out:
#   DESCRIPTION  CAMPAIGN Start_date   End_date  Campaign_Duration Start_month  \
# 0       TypeB        24 2021-10-21 2021-12-20                 60          10
# 1       TypeC        15 2021-07-01 2021-12-09                161          07
# 2       TypeB        25 2021-10-21 2021-11-22                 32          10
#
#   End_month Start_Year End_Year
# 0        12       2021     2021
# 1        12       2021     2021
# 2        11       2021     2021

# %%
CAMPAIGN_DESC_RAW['Start_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['Start_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['Start_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW['Start_date']
# Out:
# 0     2021-10-21
# 1     2021-07-01
# 2     2021-10-21
# 3     2021-09-07
# 4     2021-10-08
# 5     2021-09-16
# 6     2021-09-16
# 7     2021-08-10
# 8     2021-08-26
# 9     2021-07-29
# 10    2021-06-15
# 11    2021-07-15
# 12    2021-05-19
# 13    2021-04-22
# 14    2021-04-22
# 15    2021-04-08
# 16    2021-03-11
# 17    2021-02-16
# 18    2021-02-02
# 19    2021-01-28
# 20    2020-12-22
# 21    2021-01-12
# 22    2021-01-07
# 23    2020-12-12
# 24    2020-12-17
# 25    2020-11-19
# 26    2020-10-08
# 27    2020-09-16
# 28    2020-08-25
# 29    2020-08-12
# Name: Start_date, dtype: object

# %%
CAMPAIGN_DESC_RAW['End_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['End_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['End_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION          object
# CAMPAIGN               int8
# Start_date           object
# End_date             object
# Campaign_Duration     int16
# Start_month          object
# End_month            object
# Start_Year           object
# End_Year             object
# dtype: object

# %%
COUPON_REDEMPT_RAW.drop(['DAY'],axis=1,inplace=True)

# %%
COUPON_REDEMPT_RAW.head(3)
# Out:
#    HOUSEHOLD_KEY   COUPON_UPC  CAMPAIGN       Date
# 0              1  10000085364         8 2021-02-25
# 1              1  51700010076         8 2021-02-25
# 2              1  54200000033         8 2021-03-03

# %%
COUPON_REDEMPT_RAW['Date']=pd.to_datetime(COUPON_REDEMPT_RAW['Date']).apply(lambda x: x.date())

# %%
COUPON_REDEMPT_RAW.dtypes
# Out:
# HOUSEHOLD_KEY     int16
# COUPON_UPC        int64
# CAMPAIGN           int8
# Date             object
# dtype: object

# %%
TRANSACTION_RAW.drop(['DAY','WEEK_NO'],axis=1,inplace=True)

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  \
# 0           2056  29330027026     1106523         1         2.32       341
# 1           2056  29330027026     5567325         1         2.69       341
# 2           2056  29330027027     1106523         1         2.32       341
# 3           1873  29330097522     1135681         1         1.29       320
# 4           1602  29339301484      828427         1         0.22       334
#
#    RETAIL_DISC  TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC       Date
# 0         0.00           4            0                  0 2020-06-26
# 1         0.00           4            0                  0 2020-06-26
# 2         0.00           4            0                  0 2020-06-26
# 3         0.00           1            0                  0 2020-06-26
# 4        -0.07        1537            0                  0 2020-06-26

# %%
TRANSACTION_RAW['Date']=pd.to_datetime(TRANSACTION_RAW['Date']).apply(lambda x: x.date())

# %%
TRANSACTION_RAW.dtypes
# Out:
# HOUSEHOLD_KEY          int16
# BASKET_ID              int64
# PRODUCT_ID             int32
# QUANTITY               int32
# SALES_VALUE          float64
# STORE_ID               int32
# RETAIL_DISC          float64
# TRANS_TIME             int16
# COUPON_DISC             int8
# COUPON_MATCH_DISC       int8
# Date                  object
# dtype: object

# %%
TRANSACTION_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  \
# 0           2056  29330027026     1106523         1         2.32       341
# 1           2056  29330027026     5567325         1         2.69       341
# 2           2056  29330027027     1106523         1         2.32       341
# 3           1873  29330097522     1135681         1         1.29       320
# 4           1602  29339301484      828427         1         0.22       334
# 5           1602  29339301484      844740         2         2.50       334
# 6           1602  29339301484      847302         1         0.99       334
# 7           1602  29339301484      849202         1         7.79       334
# 8           1602  29339301484      856382         1         2.59       334
# 9           1602  29339301484      858893         1         1.39       334
#
#    RETAIL_DISC  TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC        Date
# 0         0.00           4            0                  0  2020-06-26
# 1         0.00           4            0                  0  2020-06-26
# 2         0.00           4            0                  0  2020-06-26
# 3         0.00           1            0                  0  2020-06-26
# 4        -0.07        1537            0                  0  2020-06-26
# 5        -0.68        1537            0                  0  2020-06-26
# 6        -0.50        1537            0                  0  2020-06-26
# 7         0.00        1537            0                  0  2020-06-26
# 8         0.00        1537            0                  0  2020-06-26
# 9         0.00        1537            0                  0  2020-06-26

# %% [markdown]
# #### Now loading the table to Database

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import snowflake.connector as snowCtx
from snowflake.connector.pandas_tools import write_pandas
import pandas as pd
import getpass

# %%
conn = snowflake.connector.connect(
        user = 'admin',
        ##password = getpass.getpass('Your Snowflake Password: ')
        password='Admin@12345',
        account = 'av68913.central-india.azure',
        database='RETAILS',
        warehouse='DEMO_DWH',
        SCHEMA='PUBLIC',
        schema ='PUBLIC'
 )

# %%
cur=conn.cursor()

# %%
cur.execute(''' CREATE OR REPLACE TABLE COUPON_REDEMPT_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
COUPON_UPC NUMBER(38,0),
CAMPAIGN NUMBER(38,0),
Date Date
)''')

# %%
cur.execute('''CREATE OR REPLACE TABLE TRANSACTION_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
BASKET_ID NUMBER(38,0),
PRODUCT_ID NUMBER(38,0),
QUANTITY NUMBER(38,0),
SALES_VALUE FLOAT,
STORE_ID NUMBER(38,0),
RETAIL_DISC FLOAT,
TRANS_TIME NUMBER(38,0),
COUPON_DISC FLOAT,
COUPON_MATCH_DISC FLOAT,
Date Date
)
''')

# %%
CAMPAIGN_DESC_RAW.head() ## cleaned raw dataframe
# Out:
#   DESCRIPTION  CAMPAIGN  Start_date    End_date  Campaign_Duration  \
# 0       TypeB        24  2021-10-21  2021-12-20                 60
# 1       TypeC        15  2021-07-01  2021-12-09                161
# 2       TypeB        25  2021-10-21  2021-11-22                 32
# 3       TypeC        20  2021-09-07  2021-11-16                 70
# 4       TypeB        23  2021-10-08  2021-11-15                 38
#
#   Start_month End_month Start_Year End_Year
# 0          10        12       2021     2021
# 1          07        12       2021     2021
# 2          10        11       2021     2021
# 3          09        11       2021     2021
# 4          10        11       2021     2021

# %%
cur.execute('''
CREATE OR REPLACE TABLE CAMPAIGN_DESC_NEW
(DESCRIPTION VARCHAR(10),
CAMPAIGN NUMBER(38,0),
Start_date date,
End_date  date,
Campaign_Duration NUMBER(38,0),
Start_month VARCHAR(10),
End_month VARCHAR(10),
Start_Year INT,
End_Year INT)''')

# %%
success, nchunks, nrows, _ = write_pandas(conn, CAMPAIGN_DESC_RAW,'CAMPAIGN_DESC_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,30

# %%
success, nchunks, nrows, _ = write_pandas(conn, COUPON_REDEMPT_RAW,'COUPON_REDEMPT_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,2318

# %%
success, nchunks, nrows, _ = write_pandas(conn,TRANSACTION_RAW ,'TRANSACTION_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,3046148
